# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("test.csv")
df
# Out:
#    YearsExperience  Salary
# 0                1   30000
# 1                2   35000
# 2                3   40000
# 3                4   45000
# 4                5   50000
# 5                6   55000
# 6                7   60000
# 7                8   65000
# 8                9   70000
# 9               10   75000

# %%
X = df[["YearsExperience"]]
y = df["Salary"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5
                                                    , random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
mse=mean_squared_error(y_test,y_pred)
mse
print("mean_squared_error :",mse)
r2=r2_score(y_test,y_pred)
print("r2_score :",r2*100)
# Out:
# mean_squared_error : 4.4998625322884704e-23
# r2_score : 100.0

# %%
up=model.predict([[7]])
print(up)
# Out:
# [60000.]
# C:\Users\sandy\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X_test,y_test,color='red',marker='x',label="actual")
plt.plot(X_test,y_pred,label='prediction')
plt.xlabel('X-data')
plt.ylabel('Y-data')
plt.legend()
plt.show()

# %%
data = [[30]]
pred = model.predict(data)
pred
# Out:
# C:\Users\sandy\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([175000.])
